# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import matplotlib.pyplot as plt
import numpy as np
import pyactlike

# %% [markdown]
# # Example for Cobaya (version 2.1.x)
#
# This example demonstrates how to use the ACT likelihood on versions of Cobaya less than 2.1, such as the current devel branch on GitHub. It's much simpler than the current stable release, one only needs to list `pyactlike.ACTPol_lite_DR4` as one of the likelihoods.

# %%
# Test the Cobaya interface to the ACT likelihood.
from cobaya.yaml import yaml_load
from cobaya.model import get_model

info_yaml = r"""
likelihood:
    pyactlike.ACTPol_lite_DR4:
        components: 
            - tt
            - te
            - ee
        lmax: 6000

theory:
    camb:
        stop_at_error: True
        extra_args:
            lens_potential_accuracy: 1

params:
    ns:
        prior:
          min: 0.8
          max: 1.2
        ref:
          dist: norm
          loc: 0.965
          scale: 0.004
        proposal: 0.002
        latex: n_\mathrm{s}
    H0:
        prior:
            min: 40
            max: 100
        ref:
          dist: norm
          loc: 70
          scale: 2
        proposal: 2
        latex: H_0
    yp2:
        prior:
            min: 0.9
            max: 1.1
sampler:
    mcmc:
        proposal_scale: 2.4
"""

info = yaml_load(info_yaml)
model = get_model(info)
# Out:
# [model] *WARNING* Ignored blocks/options: ['sampler']
# [camb] Importing *local* CAMB from /home/zequnl/cobaya-modules/code/CAMB

# %%
fiducial_params = {'ns': 0.97, 'H0': 68.0, 'yp2':1.0}
model.loglike(fiducial_params)[0]
# Out:
# -343.87117748882156

# %%
from cobaya.run import run
updated_info, products = run(info)
# Out:
# [camb] Importing *local* CAMB from /home/zequnl/cobaya-modules/code/CAMB
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdf's for some parameters were not provided. Sampling from the prior instead for those parameters.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {pyactlike.ACTPol_lite_DR4: 45.6, camb.transfers: 0.666, camb: 0.652}
# [mcmc] *WARNING* `i_last_slow_block` is only well defined when dragging.
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Initial point: ns:0.9709102, H0:71.48611, yp2:0.9541611
# [mcmc] Sampling! (NB: no accepted step will be saved until 60 burn-in samples have been obtained)
# [mcmc] Progress @ 2020-04-13 12:55:51 : 1 steps taken -- still burning in, 60 accepted steps left.
# [mcmc] Progress @ 2020-04-13 12:56:52 : 45 steps taken -- still burning in, 48 accepted steps left.
# [mcmc] Progress @ 2020-04-13 12:57:52 : 87 steps taken -- still burning in, 40 accepted steps left.
# [mcmc] Progress @ 2020-04-13 12:58:53 : 129 steps taken -- still burning in, 30 accepted steps left.
# [mcmc] Progress @ 2020-04-13 12:59:54 : 169 steps taken -- still burning in, 17 accepted steps left.
# [mcmc] Progress @ 2020-04-13 13:00:55 : 210 steps taken -- still burning in, 5 accepted steps left.
# [mcmc] Finished burn-in phase: discarded 60 accepted steps.
# [mcmc] Progress @ 2020-04-13 13:01:57 : 247 steps taken, and 0 accepted.
# [mcmc] Progress @ 2020-04-13 13:02:58 : 287 steps taken, and 7 accepted.
# [mcmc] Progress @ 2020-04-13 13:03:59 : 330 steps taken, and 17 accepted.
# [mcmc] Progress @ 2020-04-13 13:05:00 : 372 steps taken, and 31 accepted.
# [mcmc] Progress @ 2020-04-13 13:06:01 : 415 steps taken, and 47 accepted.
# [mcmc] Progress @ 2020-04-13 13:07:01 : 457 steps taken, and 62 accepted.
# [mcmc] Progress @ 2020-04-13 13:08:01 : 497 steps taken, and 71 accepted.
# [mcmc] Progress @ 2020-04-13 13:09:03 : 538 steps taken, and 81 accepted.
# [mcmc] Progress @ 2020-04-13 13:10:03 : 580 steps taken, and 94 accepted.
# [mcmc] Progress @ 2020-04-13 13:11:04 : 620 steps taken, and 108 accepted.
# [mcmc] Learn + convergence test @ 120 samples accepted.
# [mcmc]  - Acceptance rate: 0.286
# [mcmc]  - Convergence of means: R-1 = 0.430630 after 120 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 13:12:05 : 659 steps taken, and 124 accepted.
# [mcmc] Progress @ 2020-04-13 13:13:07 : 702 steps taken, and 158 accepted.
# [mcmc] Progress @ 2020-04-13 13:14:07 : 743 steps taken, and 187 accepted.
# [mcmc] Progress @ 2020-04-13 13:15:08 : 786 steps taken, and 219 accepted.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.414
# [mcmc]  - Convergence of means: R-1 = 0.826053 after 240 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 13:16:10 : 827 steps taken, and 247 accepted.
# [mcmc] Progress @ 2020-04-13 13:17:10 : 870 steps taken, and 273 accepted.
# [mcmc] Progress @ 2020-04-13 13:18:12 : 910 steps taken, and 294 accepted.
# [mcmc] Progress @ 2020-04-13 13:19:15 : 953 steps taken, and 316 accepted.
# [mcmc] Progress @ 2020-04-13 13:20:17 : 995 steps taken, and 341 accepted.
# [mcmc] Learn + convergence test @ 360 samples accepted.
# [mcmc]  - Acceptance rate: 0.454
# [mcmc]  - Convergence of means: R-1 = 0.484358 after 360 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 13:21:18 : 1037 steps taken, and 364 accepted.
# [mcmc] Progress @ 2020-04-13 13:22:18 : 1078 steps taken, and 389 accepted.
# [mcmc] Progress @ 2020-04-13 13:23:21 : 1120 steps taken, and 412 accepted.
# [mcmc] Progress @ 2020-04-13 13:24:21 : 1162 steps taken, and 440 accepted.
# [mcmc] Progress @ 2020-04-13 13:25:23 : 1205 steps taken, and 462 accepted.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.483
# [mcmc]  - Convergence of means: R-1 = 0.195326 after 480 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 13:26:25 : 1248 steps taken, and 492 accepted.
# [mcmc] Progress @ 2020-04-13 13:27:25 : 1290 steps taken, and 517 accepted.
# [mcmc] Progress @ 2020-04-13 13:28:27 : 1330 steps taken, and 532 accepted.
# [mcmc] Progress @ 2020-04-13 13:29:30 : 1372 steps taken, and 552 accepted.
# [mcmc] Progress @ 2020-04-13 13:30:31 : 1414 steps taken, and 571 accepted.
# [mcmc] Progress @ 2020-04-13 13:31:34 : 1457 steps taken, and 598 accepted.
# [mcmc] Learn + convergence test @ 600 samples accepted.
# [mcmc]  - Acceptance rate: 0.489
# [mcmc]  - Convergence of means: R-1 = 0.161021 after 600 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 13:32:35 : 1500 steps taken, and 624 accepted.
# [mcmc] Progress @ 2020-04-13 13:33:35 : 1540 steps taken, and 643 accepted.
# [mcmc] Progress @ 2020-04-13 13:34:38 : 1580 steps taken, and 659 accepted.
# [mcmc] Progress @ 2020-04-13 13:35:38 : 1620 steps taken, and 677 accepted.
# [mcmc] Progress @ 2020-04-13 13:36:39 : 1661 steps taken, and 703 accepted.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.495
# [mcmc]  - Convergence of means: R-1 = 0.261216 after 720 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 13:37:41 : 1704 steps taken, and 727 accepted.
# [mcmc] Progress @ 2020-04-13 13:38:42 : 1745 steps taken, and 743 accepted.
# [mcmc] Progress @ 2020-04-13 13:39:44 : 1784 steps taken, and 762 accepted.
# [mcmc] Progress @ 2020-04-13 13:40:47 : 1825 steps taken, and 786 accepted.
# [mcmc] Progress @ 2020-04-13 13:41:47 : 1863 steps taken, and 807 accepted.
# [mcmc] Progress @ 2020-04-13 13:42:47 : 1902 steps taken, and 823 accepted.
# [mcmc] Learn + convergence test @ 840 samples accepted.
# [mcmc]  - Acceptance rate: 0.494
# [mcmc]  - Convergence of means: R-1 = 0.149873 after 840 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 13:43:49 : 1946 steps taken, and 846 accepted.
# [mcmc] Progress @ 2020-04-13 13:44:50 : 1986 steps taken, and 866 accepted.
# [mcmc] Progress @ 2020-04-13 13:45:51 : 2027 steps taken, and 887 accepted.
# [mcmc] Progress @ 2020-04-13 13:46:52 : 2068 steps taken, and 908 accepted.
# [mcmc] Progress @ 2020-04-13 13:47:54 : 2110 steps taken, and 931 accepted.
# [mcmc] Progress @ 2020-04-13 13:48:57 : 2154 steps taken, and 948 accepted.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.494
# [mcmc]  - Convergence of means: R-1 = 0.125743 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 13:49:58 : 2196 steps taken, and 968 accepted.
# [mcmc] Progress @ 2020-04-13 13:51:00 : 2236 steps taken, and 984 accepted.
# [mcmc] Progress @ 2020-04-13 13:52:00 : 2277 steps taken, and 1003 accepted.
# [mcmc] Progress @ 2020-04-13 13:53:02 : 2318 steps taken, and 1020 accepted.
# [mcmc] Progress @ 2020-04-13 13:54:03 : 2359 steps taken, and 1037 accepted.
# [mcmc] Progress @ 2020-04-13 13:55:06 : 2401 steps taken, and 1054 accepted.
# [mcmc] Progress @ 2020-04-13 13:56:06 : 2441 steps taken, and 1071 accepted.
# [mcmc] Learn + convergence test @ 1080 samples accepted.
# [mcmc]  - Acceptance rate: 0.484
# [mcmc]  - Convergence of means: R-1 = 0.097191 after 1080 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 13:57:07 : 2483 steps taken, and 1086 accepted.
# [mcmc] Progress @ 2020-04-13 13:58:08 : 2527 steps taken, and 1113 accepted.
# [mcmc] Progress @ 2020-04-13 13:59:11 : 2568 steps taken, and 1128 accepted.
# [mcmc] Progress @ 2020-04-13 14:00:11 : 2607 steps taken, and 1142 accepted.
# [mcmc] Progress @ 2020-04-13 14:01:11 : 2646 steps taken, and 1157 accepted.
# [mcmc] Progress @ 2020-04-13 14:02:14 : 2686 steps taken, and 1174 accepted.
# [mcmc] Progress @ 2020-04-13 14:03:14 : 2726 steps taken, and 1191 accepted.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.478
# [mcmc]  - Convergence of means: R-1 = 0.073888 after 1200 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 14:04:15 : 2768 steps taken, and 1212 accepted.
# [mcmc] Progress @ 2020-04-13 14:05:18 : 2814 steps taken, and 1236 accepted.
# [mcmc] Progress @ 2020-04-13 14:06:18 : 2854 steps taken, and 1252 accepted.
# [mcmc] Progress @ 2020-04-13 14:07:20 : 2887 steps taken, and 1264 accepted.
# [mcmc] Progress @ 2020-04-13 14:08:22 : 2922 steps taken, and 1278 accepted.
# [mcmc] Progress @ 2020-04-13 14:09:24 : 2958 steps taken, and 1295 accepted.
# [mcmc] Progress @ 2020-04-13 14:10:25 : 3000 steps taken, and 1314 accepted.
# [mcmc] Learn + convergence test @ 1320 samples accepted.
# [mcmc]  - Acceptance rate: 0.476
# [mcmc]  - Convergence of means: R-1 = 0.061078 after 1320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 14:11:27 : 3041 steps taken, and 1334 accepted.
# [mcmc] Progress @ 2020-04-13 14:12:29 : 3083 steps taken, and 1355 accepted.
# [mcmc] Progress @ 2020-04-13 14:13:32 : 3124 steps taken, and 1369 accepted.
# [mcmc] Progress @ 2020-04-13 14:14:33 : 3164 steps taken, and 1388 accepted.
# [mcmc] Progress @ 2020-04-13 14:15:34 : 3207 steps taken, and 1406 accepted.
# [mcmc] Progress @ 2020-04-13 14:16:36 : 3249 steps taken, and 1424 accepted.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.058189 after 1440 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 14:17:37 : 3291 steps taken, and 1443 accepted.
# [mcmc] Progress @ 2020-04-13 14:18:39 : 3331 steps taken, and 1464 accepted.
# [mcmc] Progress @ 2020-04-13 14:19:42 : 3373 steps taken, and 1485 accepted.
# [mcmc] Progress @ 2020-04-13 14:20:44 : 3415 steps taken, and 1508 accepted.
# [mcmc] Progress @ 2020-04-13 14:21:46 : 3457 steps taken, and 1528 accepted.
# [mcmc] Progress @ 2020-04-13 14:22:46 : 3498 steps taken, and 1548 accepted.
# [mcmc] Learn + convergence test @ 1560 samples accepted.
# [mcmc]  - Acceptance rate: 0.474
# [mcmc]  - Convergence of means: R-1 = 0.020096 after 1560 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 14:23:49 : 3539 steps taken, and 1564 accepted.
# [mcmc] Progress @ 2020-04-13 14:24:50 : 3578 steps taken, and 1577 accepted.
# [mcmc] Progress @ 2020-04-13 14:25:51 : 3618 steps taken, and 1597 accepted.
# [mcmc] Progress @ 2020-04-13 14:26:53 : 3659 steps taken, and 1613 accepted.
# [mcmc] Progress @ 2020-04-13 14:27:56 : 3700 steps taken, and 1628 accepted.
# [mcmc] Progress @ 2020-04-13 14:28:57 : 3741 steps taken, and 1642 accepted.
# [mcmc] Progress @ 2020-04-13 14:29:58 : 3782 steps taken, and 1658 accepted.
# [mcmc] Progress @ 2020-04-13 14:31:01 : 3823 steps taken, and 1677 accepted.
# [mcmc] Learn + convergence test @ 1680 samples accepted.
# [mcmc]  - Acceptance rate: 0.468
# [mcmc]  - Convergence of means: R-1 = 0.029127 after 1680 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 14:32:03 : 3863 steps taken, and 1691 accepted.
# [mcmc] Progress @ 2020-04-13 14:33:06 : 3904 steps taken, and 1710 accepted.
# [mcmc] Progress @ 2020-04-13 14:34:07 : 3946 steps taken, and 1730 accepted.
# [mcmc] Progress @ 2020-04-13 14:35:08 : 3985 steps taken, and 1745 accepted.
# [mcmc] Progress @ 2020-04-13 14:36:11 : 4025 steps taken, and 1766 accepted.
# [mcmc] Progress @ 2020-04-13 14:37:12 : 4066 steps taken, and 1780 accepted.
# [mcmc] Progress @ 2020-04-13 14:38:13 : 4105 steps taken, and 1799 accepted.
# [mcmc] Learn + convergence test @ 1800 samples accepted.
# [mcmc]  - Acceptance rate: 0.465
# [mcmc]  - Convergence of means: R-1 = 0.026689 after 1800 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 14:39:15 : 4144 steps taken, and 1815 accepted.
# [mcmc] Progress @ 2020-04-13 14:40:16 : 4187 steps taken, and 1831 accepted.
# [mcmc] Progress @ 2020-04-13 14:41:17 : 4227 steps taken, and 1848 accepted.
# [mcmc] Progress @ 2020-04-13 14:42:17 : 4268 steps taken, and 1869 accepted.
# [mcmc] Progress @ 2020-04-13 14:43:18 : 4305 steps taken, and 1880 accepted.
# [mcmc] Progress @ 2020-04-13 14:44:18 : 4345 steps taken, and 1898 accepted.
# [mcmc] Progress @ 2020-04-13 14:45:18 : 4381 steps taken, and 1912 accepted.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.461
# [mcmc]  - Convergence of means: R-1 = 0.058270 after 1920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 14:46:19 : 4421 steps taken, and 1930 accepted.
# [mcmc] Progress @ 2020-04-13 14:47:20 : 4463 steps taken, and 1945 accepted.
# [mcmc] Progress @ 2020-04-13 14:48:21 : 4501 steps taken, and 1956 accepted.
# [mcmc] Progress @ 2020-04-13 14:49:24 : 4543 steps taken, and 1977 accepted.
# [mcmc] Progress @ 2020-04-13 14:50:24 : 4585 steps taken, and 1996 accepted.
# [mcmc] Progress @ 2020-04-13 14:51:26 : 4624 steps taken, and 2009 accepted.
# [mcmc] Progress @ 2020-04-13 14:52:26 : 4665 steps taken, and 2026 accepted.
# [mcmc] Learn + convergence test @ 2040 samples accepted.
# [mcmc]  - Acceptance rate: 0.458
# [mcmc]  - Convergence of means: R-1 = 0.026091 after 2040 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 14:53:28 : 4708 steps taken, and 2045 accepted.
# [mcmc] Progress @ 2020-04-13 14:54:29 : 4752 steps taken, and 2064 accepted.
# [mcmc] Progress @ 2020-04-13 14:55:29 : 4792 steps taken, and 2078 accepted.
# [mcmc] Progress @ 2020-04-13 14:56:30 : 4833 steps taken, and 2092 accepted.
# [mcmc] Progress @ 2020-04-13 14:57:31 : 4873 steps taken, and 2111 accepted.
# [mcmc] Progress @ 2020-04-13 14:58:32 : 4912 steps taken, and 2124 accepted.
# [mcmc] Progress @ 2020-04-13 14:59:34 : 4953 steps taken, and 2143 accepted.
# [mcmc] Progress @ 2020-04-13 15:00:34 : 4993 steps taken, and 2159 accepted.
# [mcmc] Learn + convergence test @ 2160 samples accepted.
# [mcmc]  - Acceptance rate: 0.454
# [mcmc]  - Convergence of means: R-1 = 0.017503 after 2160 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 15:01:36 : 5036 steps taken, and 2179 accepted.
# [mcmc] Progress @ 2020-04-13 15:02:37 : 5075 steps taken, and 2195 accepted.
# [mcmc] Progress @ 2020-04-13 15:03:38 : 5117 steps taken, and 2210 accepted.
# [mcmc] Progress @ 2020-04-13 15:04:41 : 5159 steps taken, and 2231 accepted.
# [mcmc] Progress @ 2020-04-13 15:05:41 : 5199 steps taken, and 2249 accepted.
# [mcmc] Progress @ 2020-04-13 15:06:41 : 5241 steps taken, and 2265 accepted.
# [mcmc] Learn + convergence test @ 2280 samples accepted.
# [mcmc]  - Acceptance rate: 0.453
# [mcmc]  - Convergence of means: R-1 = 0.020457 after 2280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 15:07:42 : 5282 steps taken, and 2283 accepted.
# [mcmc] Progress @ 2020-04-13 15:08:43 : 5323 steps taken, and 2304 accepted.
# [mcmc] Progress @ 2020-04-13 15:09:44 : 5362 steps taken, and 2320 accepted.
# [mcmc] Progress @ 2020-04-13 15:10:47 : 5405 steps taken, and 2336 accepted.
# [mcmc] Progress @ 2020-04-13 15:11:48 : 5445 steps taken, and 2358 accepted.
# [mcmc] Progress @ 2020-04-13 15:12:48 : 5485 steps taken, and 2380 accepted.
# [mcmc] Progress @ 2020-04-13 15:13:51 : 5525 steps taken, and 2400 accepted.
# [mcmc] Learn + convergence test @ 2400 samples accepted.
# [mcmc]  - Acceptance rate: 0.454
# [mcmc]  - Convergence of means: R-1 = 0.031745 after 2400 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 15:14:53 : 5567 steps taken, and 2419 accepted.
# [mcmc] Progress @ 2020-04-13 15:15:55 : 5609 steps taken, and 2437 accepted.
# [mcmc] Progress @ 2020-04-13 15:16:57 : 5653 steps taken, and 2450 accepted.
# [mcmc] Progress @ 2020-04-13 15:17:59 : 5696 steps taken, and 2475 accepted.
# [mcmc] Progress @ 2020-04-13 15:18:59 : 5735 steps taken, and 2487 accepted.
# [mcmc] Progress @ 2020-04-13 15:20:00 : 5776 steps taken, and 2498 accepted.
# [mcmc] Progress @ 2020-04-13 15:21:00 : 5816 steps taken, and 2518 accepted.
# [mcmc] Learn + convergence test @ 2520 samples accepted.
# [mcmc]  - Acceptance rate: 0.451
# [mcmc]  - Convergence of means: R-1 = 0.039280 after 2520 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 15:22:01 : 5854 steps taken, and 2537 accepted.
# [mcmc] Progress @ 2020-04-13 15:23:01 : 5893 steps taken, and 2554 accepted.
# [mcmc] Progress @ 2020-04-13 15:24:03 : 5932 steps taken, and 2570 accepted.
# [mcmc] Progress @ 2020-04-13 15:25:04 : 5971 steps taken, and 2588 accepted.
# [mcmc] Progress @ 2020-04-13 15:26:04 : 6013 steps taken, and 2603 accepted.
# [mcmc] Progress @ 2020-04-13 15:27:05 : 6055 steps taken, and 2621 accepted.
# [mcmc] Progress @ 2020-04-13 15:28:07 : 6098 steps taken, and 2637 accepted.
# [mcmc] Learn + convergence test @ 2640 samples accepted.
# [mcmc]  - Acceptance rate: 0.450
# [mcmc]  - Convergence of means: R-1 = 0.025450 after 2640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 15:29:08 : 6138 steps taken, and 2653 accepted.
# [mcmc] Progress @ 2020-04-13 15:30:09 : 6178 steps taken, and 2673 accepted.
# [mcmc] Progress @ 2020-04-13 15:31:10 : 6222 steps taken, and 2687 accepted.
# [mcmc] Progress @ 2020-04-13 15:32:12 : 6262 steps taken, and 2705 accepted.
# [mcmc] Progress @ 2020-04-13 15:33:14 : 6304 steps taken, and 2722 accepted.
# [mcmc] Progress @ 2020-04-13 15:34:15 : 6346 steps taken, and 2745 accepted.
# [mcmc] Learn + convergence test @ 2760 samples accepted.
# [mcmc]  - Acceptance rate: 0.449
# [mcmc]  - Convergence of means: R-1 = 0.016009 after 2760 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 15:35:16 : 6387 steps taken, and 2762 accepted.
# [mcmc] Progress @ 2020-04-13 15:36:19 : 6429 steps taken, and 2773 accepted.
# [mcmc] Progress @ 2020-04-13 15:37:19 : 6470 steps taken, and 2796 accepted.
# [mcmc] Progress @ 2020-04-13 15:38:20 : 6512 steps taken, and 2819 accepted.
# [mcmc] Progress @ 2020-04-13 15:39:22 : 6553 steps taken, and 2832 accepted.
# [mcmc] Progress @ 2020-04-13 15:40:23 : 6594 steps taken, and 2849 accepted.
# [mcmc] Progress @ 2020-04-13 15:41:24 : 6638 steps taken, and 2871 accepted.
# [mcmc] Learn + convergence test @ 2880 samples accepted.
# [mcmc]  - Acceptance rate: 0.449
# [mcmc]  - Convergence of means: R-1 = 0.011953 after 2880 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 15:42:26 : 6679 steps taken, and 2890 accepted.
# [mcmc] Progress @ 2020-04-13 15:43:27 : 6721 steps taken, and 2910 accepted.
# [mcmc] Progress @ 2020-04-13 15:44:27 : 6761 steps taken, and 2930 accepted.
# [mcmc] Progress @ 2020-04-13 15:45:28 : 6803 steps taken, and 2946 accepted.
# [mcmc] Progress @ 2020-04-13 15:46:29 : 6844 steps taken, and 2966 accepted.
# [mcmc] Progress @ 2020-04-13 15:47:31 : 6888 steps taken, and 2983 accepted.
# [mcmc] Learn + convergence test @ 3000 samples accepted.
# [mcmc]  - Acceptance rate: 0.449
# [mcmc]  - Convergence of means: R-1 = 0.015829 after 3000 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 15:48:33 : 6929 steps taken, and 3005 accepted.
# [mcmc] Progress @ 2020-04-13 15:49:33 : 6971 steps taken, and 3022 accepted.
# [mcmc] Progress @ 2020-04-13 15:50:35 : 7014 steps taken, and 3044 accepted.
# [mcmc] Progress @ 2020-04-13 15:51:37 : 7055 steps taken, and 3061 accepted.
# [mcmc] Progress @ 2020-04-13 15:52:37 : 7094 steps taken, and 3077 accepted.
# [mcmc] Progress @ 2020-04-13 15:53:37 : 7136 steps taken, and 3097 accepted.
# [mcmc] Progress @ 2020-04-13 15:54:39 : 7178 steps taken, and 3115 accepted.
# [mcmc] Learn + convergence test @ 3120 samples accepted.
# [mcmc]  - Acceptance rate: 0.449
# [mcmc]  - Convergence of means: R-1 = 0.013991 after 3120 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 15:55:40 : 7220 steps taken, and 3134 accepted.
# [mcmc] Progress @ 2020-04-13 15:56:40 : 7258 steps taken, and 3152 accepted.
# [mcmc] Progress @ 2020-04-13 15:57:42 : 7300 steps taken, and 3172 accepted.
# [mcmc] Progress @ 2020-04-13 15:58:42 : 7344 steps taken, and 3189 accepted.
# [mcmc] Progress @ 2020-04-13 15:59:44 : 7385 steps taken, and 3209 accepted.
# [mcmc] Progress @ 2020-04-13 16:00:47 : 7429 steps taken, and 3229 accepted.
# [mcmc] Learn + convergence test @ 3240 samples accepted.
# [mcmc]  - Acceptance rate: 0.449
# [mcmc]  - Convergence of means: R-1 = 0.010770 after 3240 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 16:01:47 : 7470 steps taken, and 3249 accepted.
# [mcmc] Progress @ 2020-04-13 16:02:48 : 7510 steps taken, and 3260 accepted.
# [mcmc] Progress @ 2020-04-13 16:03:48 : 7552 steps taken, and 3272 accepted.
# [mcmc] Progress @ 2020-04-13 16:04:51 : 7594 steps taken, and 3290 accepted.
# [mcmc] Progress @ 2020-04-13 16:05:54 : 7637 steps taken, and 3307 accepted.
# [mcmc] Progress @ 2020-04-13 16:06:55 : 7676 steps taken, and 3325 accepted.
# [mcmc] Progress @ 2020-04-13 16:07:56 : 7718 steps taken, and 3345 accepted.
# [mcmc] Learn + convergence test @ 3360 samples accepted.
# [mcmc]  - Acceptance rate: 0.447
# [mcmc]  - Convergence of means: R-1 = 0.015562 after 3360 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 16:08:56 : 7758 steps taken, and 3363 accepted.
# [mcmc] Progress @ 2020-04-13 16:09:56 : 7799 steps taken, and 3382 accepted.
# [mcmc] Progress @ 2020-04-13 16:10:58 : 7844 steps taken, and 3402 accepted.
# [mcmc] Progress @ 2020-04-13 16:12:00 : 7888 steps taken, and 3423 accepted.
# [mcmc] Progress @ 2020-04-13 16:13:00 : 7931 steps taken, and 3442 accepted.
# [mcmc] Progress @ 2020-04-13 16:14:02 : 7975 steps taken, and 3468 accepted.
# [mcmc] Learn + convergence test @ 3480 samples accepted.
# [mcmc]  - Acceptance rate: 0.448
# [mcmc]  - Convergence of means: R-1 = 0.014068 after 3480 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 16:15:03 : 8018 steps taken, and 3484 accepted.
# [mcmc] Progress @ 2020-04-13 16:16:03 : 8058 steps taken, and 3501 accepted.
# [mcmc] Progress @ 2020-04-13 16:17:03 : 8097 steps taken, and 3520 accepted.
# [mcmc] Progress @ 2020-04-13 16:18:05 : 8140 steps taken, and 3536 accepted.
# [mcmc] Progress @ 2020-04-13 16:19:05 : 8183 steps taken, and 3557 accepted.
# [mcmc] Progress @ 2020-04-13 16:20:05 : 8223 steps taken, and 3571 accepted.
# [mcmc] Progress @ 2020-04-13 16:21:06 : 8265 steps taken, and 3592 accepted.
# [mcmc] Learn + convergence test @ 3600 samples accepted.
# [mcmc]  - Acceptance rate: 0.448
# [mcmc]  - Convergence of means: R-1 = 0.011163 after 3600 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 16:22:07 : 8306 steps taken, and 3613 accepted.
# [mcmc] Progress @ 2020-04-13 16:23:09 : 8347 steps taken, and 3633 accepted.
# [mcmc] Progress @ 2020-04-13 16:24:10 : 8387 steps taken, and 3654 accepted.
# [mcmc] Progress @ 2020-04-13 16:25:11 : 8427 steps taken, and 3667 accepted.
# [mcmc] Progress @ 2020-04-13 16:26:14 : 8468 steps taken, and 3684 accepted.
# [mcmc] Progress @ 2020-04-13 16:27:15 : 8508 steps taken, and 3705 accepted.
# [mcmc] Learn + convergence test @ 3720 samples accepted.
# [mcmc]  - Acceptance rate: 0.448
# [mcmc]  - Convergence of means: R-1 = 0.021124 after 3720 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 16:28:16 : 8550 steps taken, and 3724 accepted.
# [mcmc] Progress @ 2020-04-13 16:29:17 : 8593 steps taken, and 3743 accepted.
# [mcmc] Progress @ 2020-04-13 16:30:20 : 8636 steps taken, and 3766 accepted.
# [mcmc] Progress @ 2020-04-13 16:31:20 : 8677 steps taken, and 3781 accepted.
# [mcmc] Progress @ 2020-04-13 16:32:23 : 8721 steps taken, and 3803 accepted.
# [mcmc] Progress @ 2020-04-13 16:33:24 : 8762 steps taken, and 3825 accepted.
# [mcmc] Learn + convergence test @ 3840 samples accepted.
# [mcmc]  - Acceptance rate: 0.448
# [mcmc]  - Convergence of means: R-1 = 0.023369 after 3840 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 16:34:26 : 8804 steps taken, and 3840 accepted.
# [mcmc] Progress @ 2020-04-13 16:35:27 : 8847 steps taken, and 3862 accepted.
# [mcmc] Progress @ 2020-04-13 16:36:28 : 8886 steps taken, and 3874 accepted.
# [mcmc] Progress @ 2020-04-13 16:37:29 : 8928 steps taken, and 3895 accepted.
# [mcmc] Progress @ 2020-04-13 16:38:30 : 8970 steps taken, and 3914 accepted.
# [mcmc] Progress @ 2020-04-13 16:39:31 : 9010 steps taken, and 3931 accepted.
# [mcmc] Progress @ 2020-04-13 16:40:32 : 9052 steps taken, and 3953 accepted.
# [mcmc] Learn + convergence test @ 3960 samples accepted.
# [mcmc]  - Acceptance rate: 0.449
# [mcmc]  - Convergence of means: R-1 = 0.026492 after 3960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 16:41:32 : 9095 steps taken, and 3978 accepted.
# [mcmc] Progress @ 2020-04-13 16:42:35 : 9135 steps taken, and 3993 accepted.
# [mcmc] Progress @ 2020-04-13 16:43:35 : 9176 steps taken, and 4008 accepted.
# [mcmc] Progress @ 2020-04-13 16:44:37 : 9218 steps taken, and 4029 accepted.
# [mcmc] Progress @ 2020-04-13 16:45:39 : 9261 steps taken, and 4047 accepted.
# [mcmc] Progress @ 2020-04-13 16:46:41 : 9303 steps taken, and 4069 accepted.
# [mcmc] Learn + convergence test @ 4080 samples accepted.
# [mcmc]  - Acceptance rate: 0.449
# [mcmc]  - Convergence of means: R-1 = 0.028025 after 4080 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 16:47:41 : 9343 steps taken, and 4087 accepted.
# [mcmc] Progress @ 2020-04-13 16:48:41 : 9383 steps taken, and 4101 accepted.
# [mcmc] Progress @ 2020-04-13 16:49:41 : 9422 steps taken, and 4117 accepted.
# [mcmc] Progress @ 2020-04-13 16:50:41 : 9463 steps taken, and 4138 accepted.
# [mcmc] Progress @ 2020-04-13 16:51:42 : 9504 steps taken, and 4158 accepted.
# [mcmc] Progress @ 2020-04-13 16:52:44 : 9544 steps taken, and 4170 accepted.
# [mcmc] Progress @ 2020-04-13 16:53:44 : 9585 steps taken, and 4187 accepted.
# [mcmc] Learn + convergence test @ 4200 samples accepted.
# [mcmc]  - Acceptance rate: 0.448
# [mcmc]  - Convergence of means: R-1 = 0.013939 after 4200 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 16:54:45 : 9626 steps taken, and 4203 accepted.
# [mcmc] Progress @ 2020-04-13 16:55:48 : 9665 steps taken, and 4219 accepted.
# [mcmc] Progress @ 2020-04-13 16:56:50 : 9706 steps taken, and 4235 accepted.
# [mcmc] Progress @ 2020-04-13 16:57:52 : 9748 steps taken, and 4253 accepted.
# [mcmc] Progress @ 2020-04-13 16:58:54 : 9791 steps taken, and 4271 accepted.
# [mcmc] Progress @ 2020-04-13 16:59:54 : 9832 steps taken, and 4297 accepted.
# [mcmc] Progress @ 2020-04-13 17:00:56 : 9873 steps taken, and 4317 accepted.
# [mcmc] Learn + convergence test @ 4320 samples accepted.
# [mcmc]  - Acceptance rate: 0.448
# [mcmc]  - Convergence of means: R-1 = 0.017297 after 4320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 17:01:56 : 9913 steps taken, and 4341 accepted.
# [mcmc] Progress @ 2020-04-13 17:02:59 : 9952 steps taken, and 4358 accepted.
# [mcmc] Progress @ 2020-04-13 17:04:00 : 9994 steps taken, and 4379 accepted.
# [mcmc] Progress @ 2020-04-13 17:05:01 : 10035 steps taken, and 4400 accepted.
# [mcmc] Progress @ 2020-04-13 17:06:05 : 10077 steps taken, and 4416 accepted.
# [mcmc] Progress @ 2020-04-13 17:07:06 : 10115 steps taken, and 4434 accepted.
# [mcmc] Learn + convergence test @ 4440 samples accepted.
# [mcmc]  - Acceptance rate: 0.449
# [mcmc]  - Convergence of means: R-1 = 0.014914 after 4440 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 17:08:07 : 10157 steps taken, and 4453 accepted.
# [mcmc] Progress @ 2020-04-13 17:09:10 : 10196 steps taken, and 4470 accepted.
# [mcmc] Progress @ 2020-04-13 17:10:10 : 10234 steps taken, and 4483 accepted.
# [mcmc] Progress @ 2020-04-13 17:11:14 : 10276 steps taken, and 4499 accepted.
# [mcmc] Progress @ 2020-04-13 17:12:14 : 10316 steps taken, and 4517 accepted.
# [mcmc] Progress @ 2020-04-13 17:13:16 : 10357 steps taken, and 4539 accepted.
# [mcmc] Progress @ 2020-04-13 17:14:16 : 10398 steps taken, and 4559 accepted.
# [mcmc] Learn + convergence test @ 4560 samples accepted.
# [mcmc]  - Acceptance rate: 0.449
# [mcmc]  - Convergence of means: R-1 = 0.021431 after 4560 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 17:15:17 : 10436 steps taken, and 4574 accepted.
# [mcmc] Progress @ 2020-04-13 17:16:20 : 10478 steps taken, and 4594 accepted.
# [mcmc] Progress @ 2020-04-13 17:17:21 : 10518 steps taken, and 4609 accepted.
# [mcmc] Progress @ 2020-04-13 17:18:24 : 10558 steps taken, and 4623 accepted.
# [mcmc] Progress @ 2020-04-13 17:19:26 : 10599 steps taken, and 4641 accepted.
# [mcmc] Progress @ 2020-04-13 17:20:28 : 10638 steps taken, and 4658 accepted.
# [mcmc] Progress @ 2020-04-13 17:21:28 : 10679 steps taken, and 4679 accepted.
# [mcmc] Learn + convergence test @ 4680 samples accepted.
# [mcmc]  - Acceptance rate: 0.448
# [mcmc]  - Convergence of means: R-1 = 0.016243 after 4680 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 17:22:30 : 10717 steps taken, and 4691 accepted.
# [mcmc] Progress @ 2020-04-13 17:23:32 : 10758 steps taken, and 4712 accepted.
# [mcmc] Progress @ 2020-04-13 17:24:34 : 10799 steps taken, and 4727 accepted.
# [mcmc] Progress @ 2020-04-13 17:25:35 : 10839 steps taken, and 4741 accepted.
# [mcmc] Progress @ 2020-04-13 17:26:36 : 10879 steps taken, and 4762 accepted.
# [mcmc] Progress @ 2020-04-13 17:27:38 : 10920 steps taken, and 4777 accepted.
# [mcmc] Progress @ 2020-04-13 17:28:40 : 10958 steps taken, and 4791 accepted.
# [mcmc] Learn + convergence test @ 4800 samples accepted.
# [mcmc]  - Acceptance rate: 0.447
# [mcmc]  - Convergence of means: R-1 = 0.013531 after 4800 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 17:29:41 : 10998 steps taken, and 4803 accepted.
# [mcmc] Progress @ 2020-04-13 17:30:42 : 11035 steps taken, and 4816 accepted.
# [mcmc] Progress @ 2020-04-13 17:31:42 : 11077 steps taken, and 4837 accepted.
# [mcmc] Progress @ 2020-04-13 17:32:45 : 11116 steps taken, and 4852 accepted.
# [mcmc] Progress @ 2020-04-13 17:33:46 : 11157 steps taken, and 4870 accepted.
# [mcmc] Progress @ 2020-04-13 17:34:48 : 11198 steps taken, and 4882 accepted.
# [mcmc] Progress @ 2020-04-13 17:35:51 : 11240 steps taken, and 4903 accepted.
# [mcmc] Learn + convergence test @ 4920 samples accepted.
# [mcmc]  - Acceptance rate: 0.446
# [mcmc]  - Convergence of means: R-1 = 0.018642 after 4920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 17:36:51 : 11278 steps taken, and 4922 accepted.
# [mcmc] Progress @ 2020-04-13 17:37:54 : 11317 steps taken, and 4938 accepted.
# [mcmc] Progress @ 2020-04-13 17:38:56 : 11357 steps taken, and 4952 accepted.
# [mcmc] Progress @ 2020-04-13 17:39:56 : 11395 steps taken, and 4964 accepted.
# [mcmc] Progress @ 2020-04-13 17:40:58 : 11432 steps taken, and 4978 accepted.
# [mcmc] Progress @ 2020-04-13 17:41:59 : 11472 steps taken, and 4992 accepted.
# [mcmc] Progress @ 2020-04-13 17:43:01 : 11511 steps taken, and 5005 accepted.
# [mcmc] Progress @ 2020-04-13 17:44:04 : 11549 steps taken, and 5019 accepted.
# [mcmc] Progress @ 2020-04-13 17:45:04 : 11589 steps taken, and 5037 accepted.
# [mcmc] Learn + convergence test @ 5040 samples accepted.
# [mcmc]  - Acceptance rate: 0.444
# [mcmc]  - Convergence of means: R-1 = 0.020574 after 5040 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 17:46:06 : 11631 steps taken, and 5058 accepted.
# [mcmc] Progress @ 2020-04-13 17:47:07 : 11671 steps taken, and 5073 accepted.
# [mcmc] Progress @ 2020-04-13 17:48:09 : 11710 steps taken, and 5090 accepted.
# [mcmc] Progress @ 2020-04-13 17:49:10 : 11751 steps taken, and 5107 accepted.
# [mcmc] Progress @ 2020-04-13 17:50:11 : 11790 steps taken, and 5126 accepted.
# [mcmc] Progress @ 2020-04-13 17:51:13 : 11830 steps taken, and 5144 accepted.
# [mcmc] Learn + convergence test @ 5160 samples accepted.
# [mcmc]  - Acceptance rate: 0.444
# [mcmc]  - Convergence of means: R-1 = 0.020047 after 5160 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 17:52:14 : 11869 steps taken, and 5163 accepted.
# [mcmc] Progress @ 2020-04-13 17:53:14 : 11910 steps taken, and 5176 accepted.
# [mcmc] Progress @ 2020-04-13 17:54:15 : 11950 steps taken, and 5199 accepted.
# [mcmc] Progress @ 2020-04-13 17:55:16 : 11992 steps taken, and 5212 accepted.
# [mcmc] Progress @ 2020-04-13 17:56:16 : 12032 steps taken, and 5232 accepted.
# [mcmc] Progress @ 2020-04-13 17:57:16 : 12072 steps taken, and 5254 accepted.
# [mcmc] Progress @ 2020-04-13 17:58:17 : 12113 steps taken, and 5273 accepted.
# [mcmc] Learn + convergence test @ 5280 samples accepted.
# [mcmc]  - Acceptance rate: 0.444
# [mcmc]  - Convergence of means: R-1 = 0.017927 after 5280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 17:59:19 : 12151 steps taken, and 5289 accepted.
# [mcmc] Progress @ 2020-04-13 18:00:20 : 12191 steps taken, and 5309 accepted.
# [mcmc] Progress @ 2020-04-13 18:01:22 : 12232 steps taken, and 5338 accepted.
# [mcmc] Progress @ 2020-04-13 18:02:23 : 12273 steps taken, and 5358 accepted.
# [mcmc] Progress @ 2020-04-13 18:03:24 : 12313 steps taken, and 5378 accepted.
# [mcmc] Progress @ 2020-04-13 18:04:27 : 12352 steps taken, and 5396 accepted.
# [mcmc] Learn + convergence test @ 5400 samples accepted.
# [mcmc]  - Acceptance rate: 0.445
# [mcmc]  - Convergence of means: R-1 = 0.016775 after 5400 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 18:05:29 : 12394 steps taken, and 5421 accepted.
# [mcmc] Progress @ 2020-04-13 18:06:30 : 12434 steps taken, and 5434 accepted.
# [mcmc] Progress @ 2020-04-13 18:07:31 : 12474 steps taken, and 5451 accepted.
# [mcmc] Progress @ 2020-04-13 18:08:32 : 12514 steps taken, and 5471 accepted.
# [mcmc] Progress @ 2020-04-13 18:09:32 : 12554 steps taken, and 5494 accepted.
# [mcmc] Progress @ 2020-04-13 18:10:34 : 12594 steps taken, and 5511 accepted.
# [mcmc] Learn + convergence test @ 5520 samples accepted.
# [mcmc]  - Acceptance rate: 0.446
# [mcmc]  - Convergence of means: R-1 = 0.015389 after 5520 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 18:11:36 : 12634 steps taken, and 5525 accepted.
# [mcmc] Progress @ 2020-04-13 18:12:37 : 12673 steps taken, and 5536 accepted.
# [mcmc] Progress @ 2020-04-13 18:13:38 : 12712 steps taken, and 5554 accepted.
# [mcmc] Progress @ 2020-04-13 18:14:40 : 12750 steps taken, and 5568 accepted.
# [mcmc] Progress @ 2020-04-13 18:15:40 : 12788 steps taken, and 5587 accepted.
# [mcmc] Progress @ 2020-04-13 18:16:41 : 12827 steps taken, and 5610 accepted.
# [mcmc] Progress @ 2020-04-13 18:17:41 : 12865 steps taken, and 5629 accepted.
# [mcmc] Learn + convergence test @ 5640 samples accepted.
# [mcmc]  - Acceptance rate: 0.446
# [mcmc]  - Convergence of means: R-1 = 0.016799 after 5640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 18:18:42 : 12905 steps taken, and 5649 accepted.
# [mcmc] Progress @ 2020-04-13 18:19:43 : 12942 steps taken, and 5667 accepted.
# [mcmc] Progress @ 2020-04-13 18:20:46 : 12984 steps taken, and 5689 accepted.
# [mcmc] Progress @ 2020-04-13 18:21:46 : 13025 steps taken, and 5709 accepted.
# [mcmc] Progress @ 2020-04-13 18:22:47 : 13067 steps taken, and 5723 accepted.
# [mcmc] Progress @ 2020-04-13 18:23:47 : 13106 steps taken, and 5729 accepted.
# [mcmc] Progress @ 2020-04-13 18:24:48 : 13145 steps taken, and 5744 accepted.
# [mcmc] Learn + convergence test @ 5760 samples accepted.
# [mcmc]  - Acceptance rate: 0.445
# [mcmc]  - Convergence of means: R-1 = 0.016687 after 5760 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 18:25:50 : 13186 steps taken, and 5760 accepted.
# [mcmc] Progress @ 2020-04-13 18:26:52 : 13226 steps taken, and 5782 accepted.
# [mcmc] Progress @ 2020-04-13 18:27:54 : 13267 steps taken, and 5797 accepted.
# [mcmc] Progress @ 2020-04-13 18:28:56 : 13307 steps taken, and 5815 accepted.
# [mcmc] Progress @ 2020-04-13 18:29:57 : 13347 steps taken, and 5836 accepted.
# [mcmc] Progress @ 2020-04-13 18:30:58 : 13387 steps taken, and 5852 accepted.
# [mcmc] Progress @ 2020-04-13 18:31:59 : 13429 steps taken, and 5873 accepted.
# [mcmc] Learn + convergence test @ 5880 samples accepted.
# [mcmc]  - Acceptance rate: 0.445
# [mcmc]  - Convergence of means: R-1 = 0.011675 after 5880 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2020-04-13 18:32:59 : 13467 steps taken, and 5890 accepted.
# [mcmc] Progress @ 2020-04-13 18:34:02 : 13506 steps taken, and 5909 accepted.

# %%
# Export the results to GetDist
from getdist.mcsamples import MCSamplesFromCobaya

gd_sample = MCSamplesFromCobaya(updated_info, products["sample"])
# Analyze and plot
mean = gd_sample.getMeans()[:3]
covmat = gd_sample.getCovMat().matrix[:3, :3]
print("Mean:")
print(mean)
print("Covariance matrix:")
print(covmat)
# %matplotlib inline  # uncomment if running from the Jupyter notebook
import getdist.plots as gdplt

gdplot = gdplt.getSubplotPlotter()
gdplot.triangle_plot(gd_sample, ["ns", "H0", "yp2"], filled=True)

# %% [markdown]
# # Combining with Planck
#
# You can use the convenience class in order to combine with Planck. This cuts the large scale temperature ACT data, to avoid double-counting issues.

# %%
info_yaml = r"""
likelihood:
    pyactlike.ACTPol_lite_DR4_for_combining_with_Planck:

theory:
    camb:
        stop_at_error: True
        extra_args:
            lens_potential_accuracy: 1

params:
    ns:
        prior:
          min: 0.8
          max: 1.2
        ref:
          dist: norm
          loc: 0.965
          scale: 0.004
        proposal: 0.002
        latex: n_\mathrm{s}
    H0:
        prior:
            min: 40
            max: 100
        ref:
          dist: norm
          loc: 70
          scale: 2
        proposal: 2
        latex: H_0
    yp2:
        prior:
            min: 0.9
            max: 1.1
sampler:
    mcmc:
        proposal_scale: 2.4
"""

info = yaml_load(info_yaml)
model = get_model(info)

fiducial_params = {'ns': 0.97, 'H0': 68.0, 'yp2':1.0}
model.loglike(fiducial_params)[0]
# Out:
# [model] *WARNING* Ignored blocks/options: ['sampler']
# [camb] Importing *local* CAMB from /home/zequnl/cobaya-modules/code/CAMB
# -275.3490505787051
